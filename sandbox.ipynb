# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
from datetime import datetime

data_path = 'data/'

def get_soup(url):
    #read html
    f = urllib.request.urlopen(url)
    page_bytes = f.read()
    page = page_bytes
    f.close()

    #parse
    soup = BeautifulSoup(page,'html.parser')
    return(soup)

# %% [markdown]
# ## Category List

# %%
soup = get_soup('https://www.kaidee.com/categories')

# %%
cat_name = [f'{s.find("a")["data-test-id"]}' for s in soup.find_all('li', class_='category-list-item')]
cat_url = [f'https://www.kaidee.com{s.find("a")["href"]}' for s in soup.find_all('li', class_='category-list-item')]
cat_df = pd.DataFrame({'cat_name':cat_name,'cat_url':cat_url})
cat_df['is_btn'] = cat_df.cat_name.apply(lambda x: 1 if 'btn' in x else 0)
cat_df.to_csv(f'{data_path}cat_df.csv',index=False)
cat_df
# Out:
#                          cat_name  \
# 0                    phone_device
# 1                        computer
# 2                           music
# 3                           sport
# 4                        bicycles
# 5                     mom_and_kid
# 6                             bag
# 7                           watch
# 8                           shoes
# 9                         fashion
# 10                  beauty_health
# 11          appliances_decoration
# 12                         amulet
# 13                     collection
# 14              baan-category-btn
# 15               rod-category-btn
# 16  commercial-truck-category-btn
# 17     other-vehicle-category-btn
# 18         auto-part-category-btn
# 19        motorcycle-category-btn
# 20                        cameras
# 21                       electric
# 22                           game
# 23                            pet
# 24                      lifestyle
# 25           job_business_service
# 26               business_service
# 27              farm-category-btn
# 28                         travel
# 29                      education
# 30                       donation
#
#                                               cat_url  is_btn
# 0            https://www.kaidee.com/c29-phone_device/       0
# 1                https://www.kaidee.com/c27-computer/       0
# 2                   https://www.kaidee.com/c60-music/       0
# 3                   https://www.kaidee.com/c61-sport/       0
# 4               https://www.kaidee.com/c123-bicycles/       0
# 5            https://www.kaidee.com/c130-mom_and_kid/       0
# 6                     https://www.kaidee.com/c95-bag/       0
# 7                   https://www.kaidee.com/c99-watch/       0
# 8                   https://www.kaidee.com/c96-shoes/       0
# 9                  https://www.kaidee.com/c5-fashion/       0
# 10           https://www.kaidee.com/c6-beauty_health/       0
# 11   https://www.kaidee.com/c3-appliances_decoration/       0
# 12                 https://www.kaidee.com/c57-amulet/       0
# 13            https://www.kaidee.com/c103-collection/       0
# 14     https://www.kaidee.comhttps://baan.kaidee.com/       1
# 15      https://www.kaidee.comhttps://rod.kaidee.com/       1
# 16  https://www.kaidee.comhttps://rod.kaidee.com/c...       1
# 17  https://www.kaidee.comhttps://rod.kaidee.com/c...       1
# 18             https://www.kaidee.com/c270-auto_part/       1
# 19  https://www.kaidee.com/c12-motorcycle-motorcycle/       1
# 20                https://www.kaidee.com/c28-cameras/       0
# 21               https://www.kaidee.com/c70-electric/       0
# 22                   https://www.kaidee.com/c31-game/       0
# 23                    https://www.kaidee.com/c62-pet/       0
# 24              https://www.kaidee.com/c10-lifestyle/       0
# 25    https://www.kaidee.com/c7-job_business_service/       0
# 26       https://www.kaidee.com/c45-business_service/       0
# 27                        https://www.kaidee.com/farm       1
# 28                  https://www.kaidee.com/c9-travel/       0
# 29               https://www.kaidee.com/c8-education/       0
# 30              https://www.kaidee.com/c283-donation/       0

# %%
# sub_cat_dfs = []
# for _,row in tqdm_notebook(cat_df[cat_df.is_btn==0].iterrows()):
#     cat_name=row['cat_name']
#     cat_url=row['cat_url']
#     cat_page = get_soup(cat_url)
#     sub_cats = cat_page.find('ul',class_='category-box-rod-min children-cate reset').find_all('li')
#     sub_cat_names = [i.find('a')['data-test-id'] for i in sub_cats] 
#     sub_cat_urls = [f"https://www.kaidee.com{i.find('a')['href']}" for i in sub_cats]
#     sub_cat_df = pd.DataFrame({'cat_name':cat_name,'cat_url':cat_url,
#                                'sub_cat_name':sub_cat_names,'sub_cat_url':sub_cat_urls})
#     sub_cat_dfs.append(sub_cat_df)
# big_cat_df = pd.concat(sub_cat_dfs)
# big_cat_df.head()
# big_cat_df.reset_index(inplace=True)
# big_cat_df = big_cat_df.iloc[:,1:]
# big_cat_df.to_csv(f'{data_path}big_cat_df.csv',index=False)

# %%
big_cat_df = pd.read_csv(f'{data_path}big_cat_df.csv')
print(big_cat_df.shape)
big_cat_df.head()
# Out:
# (146, 4)
#        cat_name                                   cat_url  \
# 0  phone_device  https://www.kaidee.com/c29-phone_device/
# 1  phone_device  https://www.kaidee.com/c29-phone_device/
# 2  phone_device  https://www.kaidee.com/c29-phone_device/
# 3  phone_device  https://www.kaidee.com/c29-phone_device/
# 4      computer      https://www.kaidee.com/c27-computer/
#
#                   sub_cat_name  \
# 0               โทรศัพท์มือถือ
# 1                     แท็บเล็ต
# 2  อุปกรณ์เสริมมือถือ แท็บเล็ต
# 3           อุปกรณ์สื่อสารอื่น
# 4          คอมพิวเตอร์ตั้งโต๊ะ
#
#                                          sub_cat_url
# 0  https://www.kaidee.com/c89-phone_device-mobile...
# 1    https://www.kaidee.com/c83-phone_device-tablet/
# 2  https://www.kaidee.com/c90-phone_device-access...
# 3  https://www.kaidee.com/c91-phone_device-other_...
# 4            https://www.kaidee.com/c81-computer-pc/

# %% [markdown]
# ## All Products in Category

# %%
cat_url = big_cat_df.sub_cat_url[0]
cat_name = big_cat_df.sub_cat_name[0]

#get total products
cat_page = get_soup(cat_url)
total_products = int(cat_page.find('span',class_='total-ad').get_text().replace(',',''))
total_pages = int(total_products/nb_products)
max_pages = 800 #can show only 800 pages max

# %%
total_products, total_pages, max_pages
# Out:
# (9653, 482, 800)

# %%
cat_url,cat_name
# Out:
# ('https://www.kaidee.com/c89-phone_device-mobilephone/', 'โทรศัพท์มือถือ')

# %%
idx = [0,1,10,20,21] #category of interest
df = big_cat_df.merge(cat_df.iloc[idx,:1],how='inner')
print(df.shape)
df
# Out:
# (22, 4)
#          cat_name                                   cat_url  \
# 0    phone_device  https://www.kaidee.com/c29-phone_device/
# 1    phone_device  https://www.kaidee.com/c29-phone_device/
# 2    phone_device  https://www.kaidee.com/c29-phone_device/
# 3    phone_device  https://www.kaidee.com/c29-phone_device/
# 4        computer      https://www.kaidee.com/c27-computer/
# 5        computer      https://www.kaidee.com/c27-computer/
# 6        computer      https://www.kaidee.com/c27-computer/
# 7        computer      https://www.kaidee.com/c27-computer/
# 8   beauty_health  https://www.kaidee.com/c6-beauty_health/
# 9   beauty_health  https://www.kaidee.com/c6-beauty_health/
# 10  beauty_health  https://www.kaidee.com/c6-beauty_health/
# 11        cameras       https://www.kaidee.com/c28-cameras/
# 12        cameras       https://www.kaidee.com/c28-cameras/
# 13        cameras       https://www.kaidee.com/c28-cameras/
# 14        cameras       https://www.kaidee.com/c28-cameras/
# 15        cameras       https://www.kaidee.com/c28-cameras/
# 16       electric      https://www.kaidee.com/c70-electric/
# 17       electric      https://www.kaidee.com/c70-electric/
# 18       electric      https://www.kaidee.com/c70-electric/
# 19       electric      https://www.kaidee.com/c70-electric/
# 20       electric      https://www.kaidee.com/c70-electric/
# 21       electric      https://www.kaidee.com/c70-electric/
#
#                    sub_cat_name  \
# 0                โทรศัพท์มือถือ
# 1                      แท็บเล็ต
# 2   อุปกรณ์เสริมมือถือ แท็บเล็ต
# 3            อุปกรณ์สื่อสารอื่น
# 4           คอมพิวเตอร์ตั้งโต๊ะ
# 5                      โน๊ตบุ๊ค
# 6               Printer Scanner
# 7       อุปกรณ์คอมพิวเตอร์อื่นๆ
# 8        อุปกรณ์เกี่ยวกับสุขภาพ
# 9                        น้ำหอม
# 10              อุปกรณ์เสริมสวย
# 11                 กล้องดิจิตอล
# 12                  กล้องวิดีโอ
# 13                   กล้องอื่นๆ
# 14                        เลนส์
# 15     อุปกรณ์เสริมกล้อง อื่น ๆ
# 16                         แอร์
# 17                      ตู้เย็น
# 18            ทีวี โฮมเธียเตอร์
# 19                เครื่องซักผ้า
# 20          เคเบิ้ล จานดาวเทียม
# 21          เครื่องใช้ไฟฟ้าอื่น
#
#                                           sub_cat_url
# 0   https://www.kaidee.com/c89-phone_device-mobile...
# 1     https://www.kaidee.com/c83-phone_device-tablet/
# 2   https://www.kaidee.com/c90-phone_device-access...
# 3   https://www.kaidee.com/c91-phone_device-other_...
# 4             https://www.kaidee.com/c81-computer-pc/
# 5       https://www.kaidee.com/c82-computer-notebook/
# 6   https://www.kaidee.com/c84-computer-printer_sc...
# 7       https://www.kaidee.com/c85-computer-other_it/
# 8   https://www.kaidee.com/c153-beauty_health-medi...
# 9   https://www.kaidee.com/c160-beauty_health-perf...
# 10  https://www.kaidee.com/c38-beauty_health-beaut...
# 11  https://www.kaidee.com/c86-cameras-digital_cam...
# 12  https://www.kaidee.com/c135-cameras-video_camera/
# 13  https://www.kaidee.com/c136-cameras-others_cam...
# 14           https://www.kaidee.com/c87-cameras-lens/
# 15  https://www.kaidee.com/c88-cameras-other_camer...
# 16  https://www.kaidee.com/c75-electric-airconditi...
# 17  https://www.kaidee.com/c76-electric-refrigerator/
# 18  https://www.kaidee.com/c77-electric-tv_homethe...
# 19  https://www.kaidee.com/c78-electric-washingmac...
# 20  https://www.kaidee.com/c79-electric-cable_sate...
# 21  https://www.kaidee.com/c80-electric-other_elec...

# %%
sub_cat_url = big_cat_df.sub_cat_url[0]
sub_cat_name = big_cat_df.sub_cat_name[0]

listing_dicts = []
for i in tqdm_notebook(range(max_pages)):
    for condition in [1,2]: #new and old
        #get soup of listing page
        page = get_soup(f'{sub_cat_url}p-{i+1}?condition={condition}')
        listings = page.find_all('a',class_='crow')
        #iterate through all listings
        for listing in listings[:-1]:
            #dict
            listing_name = listing.find('h3').get_text()
            listing_url = f"https://www.kaidee.com{listing['href']}"
            listing_price = listing.find('meta', itemprop='price')['content']
            listing_region = listing.find('meta', itemprop='addressRegion')['content']
            listing_locality = listing.find('meta', itemprop='addressLocality')['content']
            listing_lat = listing.find('meta', itemprop='latitude')['content']
            listing_lon = listing.find('meta', itemprop='longitude')['content']
            listing_dict = {
                'sub_cat_name': sub_cat_name.replace(' ','_'),
                'page': i+1,
                'condition': condition,
                'listing_name': listing_name.lower(),
                'listing_url': listing_url,
                'listing_price':listing_price,
                'listing_region':listing_region,
                'listing_locality':listing_locality,
                'listing_lat':listing_lat,
                'listing_lon':listing_lon
            } 
            listing_dicts.append(listing_dict)

        #save after x page done
        if i % 1 ==0:
            listing_df = pd.DataFrame(listing_dicts)[['sub_cat_name','page','condition',
                                                  'listing_name',
                                                  'listing_price',
                                                  'listing_url',
                                                  'listing_region',
                                                  'listing_locality',
                                                  'listing_lat','listing_lon']]
            today = str(datetime.today())[:10].replace('-','')
            fname = f"{data_path}{sub_cat_name.replace(' ','_')}_{today}.csv"
            listing_df.to_csv(fname,index=False)
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
